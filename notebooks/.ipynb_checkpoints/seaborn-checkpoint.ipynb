# %% [markdown]
# # git2net analysis for the seaborn repository
#
# First we clone the repo

# %%
import pygit2 as git2
import os
import shutil
import git2net
import pathpy as pp
import sqlite3
import pandas as pd
from datetime import date, datetime, timedelta
import matplotlib.pyplot as plt
import json 
import math
import copy

git_repo_url = 'https://github.com/mwaskom/seaborn.git'
local_directory = '.'
git_repo_dir = 'repos/seaborn4analysis'
sqlite_db_file = 'databases/seaborn_rename.db'

# %% [markdown]
# Clone repo:

# %%
if os.path.exists(git_repo_dir):
    shutil.rmtree(git_repo_dir)

repo = git2.clone_repository(git_repo_url, git_repo_dir) # Clones a non-bare repository

# %% [markdown]
# Then we create the database for it. We will try with max_modification=100, so that most commits are processed.
#
# Mine repo:

# %%
# Remove database if exists
#if os.path.exists(sqlite_db_file):
#    os.remove(sqlite_db_file)

max_modifications = 100
    
git2net.mine_git_repo(git_repo_dir, sqlite_db_file, max_modifications=max_modifications)

# %% [markdown]
# Let's check the commits that had more than 100 files modified

# %%
git2net.mining_state_summary(git_repo_dir, sqlite_db_file)

# %% [markdown]
# ### Database modification
# Replacing the aliases belonging to the same person.

# %%
#con = sqlite3.connect(sqlite_db_file)

# Query the db
#data = pd.read_sql("""SELECT * FROM commits""", con)

# Get all the name-email pairs
names = data[['author_email', 'author_name']].copy()
names.groupby(['author_email', 'author_name']).size().reset_index().rename(columns={0:'count'})

# After adding the similar names to the aliases.json, replace the values
#with open('aliases.json') as file:
#    aliases = json.load(file)

#data = data.replace(aliases)

# Save changes in db
#data.to_sql('commits', con, if_exists='replace')

# %%
con = sqlite3.connect(sqlite_db_file)

# Query the db
data = pd.read_sql("""SELECT * FROM commits""", con)

with open('notebooks/replace_chars.json') as file:
    replace_dict = json.load(file)

#print(data['author_name'].unique())
#print(replace_dict)
for key, value in replace_dict.items():
    data['author_name'] = data['author_name'].str.replace(key, value)
#data['author_name'].unique()
data.to_sql('commits', con, if_exists='replace')

# %%
print(data['author_name'].unique())
print(replace_dict)
for key, value in replace_dict.items():
    data['author_name'] = data['author_name'].str.replace(key, value)
data['author_name'].unique()

# %% [markdown]
# ### Co-author networks

# %% [markdown]
# Now let's visualize the result

# %%
t, node_info, edge_info = git2net.get_coediting_network(sqlite_db_file)
pp.Network.from_temporal_network(t)

# %% [markdown]
# which files were edited by the authors

# %%
t, node_info, edge_info = git2net.get_bipartite_network(sqlite_db_file)
n = pp.Network.from_temporal_network(t)

colour_map = {'author': '#73D2DE', 'file': '#2E5EAA'}
node_color = {node: colour_map[node_info['class'][node]] for node in n.nodes}
pp.visualisation.plot(n, node_color=node_color)

# %% [markdown]
# Co-authorship network

# %%
n, node_info, edge_info = git2net.get_coauthorship_network(sqlite_db_file)
n

# %% [markdown]
# The network is too complex because we consider the whole timeframe of the repository since its creation. Therefore we need to filter the time dimensin, and in order to do that we nee to find the first and last commit in the repo.

# %%
db = sqlite3.connect(sqlite_db_file)
max_date = datetime.strptime(pd.read_sql_query("SELECT max(committer_date) as max FROM commits", db)['max'].item(), '%Y-%m-%d %H:%M:%S')
min_date = datetime.strptime(pd.read_sql_query("SELECT min(committer_date) as min FROM commits", db)['min'].item(), '%Y-%m-%d %H:%M:%S')

print('Min date: ', min_date)
print('Max date: ', max_date)
# Out:
# Min date:  2012-06-18 11:40:27
# Max date:  2021-03-06 17:26:32

# %% [markdown]
# In order not to select an 'empty' time period (relatively few commits, e.g. holiday season), it's also worth observing the number of commits over time.

# %%
pdCommits = pd.read_sql_query("SELECT * FROM commits", db)

days = {(min_date+timedelta(days=x)).date() : 0 for x in range((max_date-min_date).days + 1)}

commit_dates = pdCommits['committer_date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S').date()).value_counts()

for key in commit_dates.keys():
    days[key] = commit_dates.get(key)

keys = days.keys()
values = days.values()
plt.figure(figsize=(20,5))
plt.bar(keys, values)
# Out:
# <BarContainer object of 3184 artists>

# %% [markdown]
# Let's choose the year 2020 based on the plot, as that was the busiest year.

# %%
time_from = datetime(2020, 1, 1)
time_to = datetime(2020, 12, 31)
n, node_info, edge_info = git2net.get_coauthorship_network(sqlite_db_file, time_from=time_from, time_to=time_to)
n

# %% [markdown]
# We can set the node size based on the number of degrees each author has in the network. This emphasizes who collaborate more with the others in the given timeframe.

# %%
node_style = zip(n.nodes, n.node_properties('degree'))
style = {}
style['node_size'] = {v:3+u for v,u in node_style}
pp.visualisation.plot(n, **style)

# %% [markdown]
# ## Bipartite networks
# Because our network changes over time, we would like to visualize each year consecutively one after the other. We can use the pathpy temporal networks for this.

# %%
def collab_network(sqlite_db_file, min_date, max_date):
    #start = int(datetime.timestamp(min_date))
    #end = int(datetime.timestamp(max_date))

    t, node_info, edge_info = git2net.get_bipartite_network(sqlite_db_file, time_from=min_date, time_to=max_date)
    n = pp.Network.from_temporal_network(t)

    

    new_n = copy.deepcopy(n)
    
    for node in n.nodes:
        if node_info['class'][node] == 'file':
            new_n.remove_node(node)

    for node in new_n.nodes:
        for f in n.successors[node]:
            for pre in n.predecessors[f]:
                if not node == pre:
                    new_n.add_edge(node, pre)

    
    return new_n

# %%
time_from = datetime(2013, 1, 1)
time_to = datetime(2014, 12, 31)
interval = timedelta(days=60)
delta = timedelta(days=60)


t2 = pp.TemporalNetwork()

rounds = math.ceil((time_to - time_from - interval)/delta)+1
for i in range(1,rounds):
    print('Round {i}/{r}'.format(i=i, r=rounds), end = "\r")
    start = time_from + i * delta
    end = time_from + i * delta + interval
    network = collab_network(sqlite_db_file, start, end)

    for edge in network.edges:
        t2.add_edge(edge[0], edge[1], i)

style = {    
  'ts_per_frame': 1, 
  'ms_per_frame': 700,
  'look_ahead': 1, 
  'look_behind': 1, 
  'inactive_edge_width': 2,
  'active_edge_width': 4, 
  'label_color' : '#000000',
  'label_size' : '8px',
  'label_offset': [0,5]
  }
print(t2)
pp.visualisation.plot(t2, **style)
# Out:
# Nodes:			32
# Time-stamped links:	132
# Links/Nodes:		4.125
# Observation period:	[1, 12]
# Observation length:	 11
# Time stamps:		 12
# Avg. inter-event dt:	 1.0
# Min/Max inter-event dt:	 1/1
# <style>
#     text.active_vXsvMnyk {
#         text-anchor: middle;
#         font-size: 8px;
#         font-family: Arial, Helvetica, sans-serif;
#         fill: #000000;
#         opacity: 1.0;
#     }
#     text.hidden_vXsvMnyk {
#         opacity: 0;
#     }
#     line.tlinks_vXsvMnyk {
#         stroke: #cccccc;
#         stroke-opacity: 0.4;
#         stroke-width: 2;
#     }
#     line.active_vXsvMnyk {
#         stroke: #ff0000;
#         stroke-opacity: 1.0;
#         stroke-width: 4;
#     }
#     line.hidden_vXsvMnyk {
#         stroke: rgb(255, 255, 255);
#         stroke-opacity: 0;
#         stroke-width: 0px;
#     }
#     circle.active_vXsvMnyk {
#         stroke: #222;
#         fill: #ff0000;
#         fill-opacity: 1;
#         stroke-width: 2px;
#     }
#     circle.tnodes_vXsvMnyk {
#         fill: #cccccc;
#         stroke: #222;
#         fill-opacity: 1;
#         stroke-width: 1.5px;
#     }
# </style>
#
# <svg width="400" height="400" id="vXsvMnyk">
#     <text x="10" y="20" font-family="sans-serif" font-size="14px" fill="red"
#         id='vXsvMnyk_time_txt'>t</text>
#     <text x="120" y="20" font-family="sans-serif" font-size="14px" fill="#9999bb" style="cursor: pointer"
#         id='vXsvMnyk_start_txt'>stop</text>
#     <text x="170" y="20" font-family="sans-serif" font-size="14px" fill="#9999bb" style="cursor: pointer"
#         id='vXsvMnyk_restart_txt'>restart</text>
# </svg>
#
# <script charset="utf-8" src="https://d3js.org/d3.v4.min.js"></script>
# <script charset="utf-8">
#
# // Load via requireJS if available (jupyter notebook environment)
# try {
#     // Problem: require.config will raise an exception when called for the second time
#     require.config({
#         paths: {
#             //d3: "https://d3js.org/d3.v4.min"
#             d3: "https://d3js.org/d3.v4.min.js".replace(".js", "")
#         }
#     });
#     console.log("Detected requireJS");
# }
# catch(err){
#     // a reference error indicates that requireJS does not exist.
#     // other errors may occur due to multiple calls to config
#     if (err instanceof ReferenceError){
#         console.log("Detected no requireJS");
#
#         // Helper function that waits for d3js to be loaded
#         require = function require(symbols, callback) {
#             var ms = 5;
#             window.setTimeout(function(t) {
#                 if (window[symbols[0]])
#                     callback(window[symbols[0]]);
#                 else
#                     window.setTimeout(arguments.callee, ms);
#             }, ms);
#         }
#     }
# }
#
# require(["d3"], function(d3) {
#     d3.selection.prototype.moveToFront = function() {
#         return this.each(function(){
#             this.parentNode.appendChild(this);
#         });
#     };
#
#     d3.selection.prototype.moveToBack = function() {
#         return this.each(function() {
#             var firstChild = this.parentNode.firstChild;
#             if (firstChild) {
#                 this.parentNode.insertBefore(this, firstChild);
#             }
#         });
#     };
#
#     var svg = d3.select("#vXsvMnyk"),
#         width = +svg.attr("width"),
#         height = +svg.attr("height"),
#         radius = 8,
#         color = d3.scaleOrdinal(d3.schemeCategory20b);
#
#     var temporal_net = {"nodes": [{"id": "n_2", "group": 1}, {"id": "n_1", "group": 1}, {"id": "n_7", "group": 1}, {"id": "n_5", "group": 1}, {"id": "n_4", "group": 1}, {"id": "n_3", "group": 1}, {"id": "n_6", "group": 1}, {"id": "n_8", "group": 1}, {"id": "n_9", "group": 1}, {"id": "n_10", "group": 1}, {"id": "n_11", "group": 1}, {"id": "n_12", "group": 1}, {"id": "n_13", "group": 1}, {"id": "n_15", "group": 1}, {"id": "n_17", "group": 1}, {"id": "n_14", "group": 1}, {"id": "n_19", "group": 1}, {"id": "n_16", "group": 1}, {"id": "n_22", "group": 1}, {"id": "n_20", "group": 1}, {"id": "n_21", "group": 1}, {"id": "n_24", "group": 1}, {"id": "n_23", "group": 1}, {"id": "n_25", "group": 1}, {"id": "n_26", "group": 1}, {"id": "n_27", "group": 1}, {"id": "n_29", "group": 1}, {"id": "n_28", "group": 1}, {"id": "n_31", "group": 1}, {"id": "n_30", "group": 1}, {"id": "n_32", "group": 1}, {"id": "n_33", "group": 1}], "links": [{"source": "n_2", "target": "n_1", "width": 1, "time": 1}, {"source": "n_1", "target": "n_2", "width": 1, "time": 1}, {"source": "n_1", "target": "n_2", "width": 1, "time": 2}, {"source": "n_2", "target": "n_1", "width": 1, "time": 2}, {"source": "n_2", "target": "n_1", "width": 1, "time": 3}, {"source": "n_1", "target": "n_2", "width": 1, "time": 3}, {"source": "n_1", "target": "n_2", "width": 1, "time": 4}, {"source": "n_2", "target": "n_1", "width": 1, "time": 4}, {"source": "n_1", "target": "n_2", "width": 1, "time": 5}, {"source": "n_1", "target": "n_7", "width": 1, "time": 5}, {"source": "n_1", "target": "n_5", "width": 1, "time": 5}, {"source": "n_1", "target": "n_4", "width": 1, "time": 5}, {"source": "n_3", "target": "n_2", "width": 1, "time": 5}, {"source": "n_2", "target": "n_4", "width": 1, "time": 5}, {"source": "n_2", "target": "n_1", "width": 1, "time": 5}, {"source": "n_2", "target": "n_6", "width": 1, "time": 5}, {"source": "n_2", "target": "n_3", "width": 1, "time": 5}, {"source": "n_2", "target": "n_8", "width": 1, "time": 5}, {"source": "n_2", "target": "n_5", "width": 1, "time": 5}, {"source": "n_2", "target": "n_7", "width": 1, "time": 5}, {"source": "n_4", "target": "n_2", "width": 1, "time": 5}, {"source": "n_4", "target": "n_1", "width": 1, "time": 5}, {"source": "n_5", "target": "n_1", "width": 1, "time": 5}, {"source": "n_5", "target": "n_2", "width": 1, "time": 5}, {"source": "n_6", "target": "n_2", "width": 1, "time": 5}, {"source": "n_7", "target": "n_1", "width": 1, "time": 5}, {"source": "n_7", "target": "n_2", "width": 1, "time": 5}, {"source": "n_8", "target": "n_2", "width": 1, "time": 5}, {"source": "n_2", "target": "n_9", "width": 1, "time": 6}, {"source": "n_2", "target": "n_10", "width": 1, "time": 6}, {"source": "n_2", "target": "n_1", "width": 1, "time": 6}, {"source": "n_9", "target": "n_2", "width": 1, "time": 6}, {"source": "n_1", "target": "n_2", "width": 1, "time": 6}, {"source": "n_10", "target": "n_2", "width": 1, "time": 6}, {"source": "n_2", "target": "n_1", "width": 1, "time": 7}, {"source": "n_2", "target": "n_11", "width": 1, "time": 7}, {"source": "n_2", "target": "n_9", "width": 1, "time": 7}, {"source": "n_2", "target": "n_12", "width": 1, "time": 7}, {"source": "n_2", "target": "n_13", "width": 1, "time": 7}, {"source": "n_1", "target": "n_2", "width": 1, "time": 7}, {"source": "n_1", "target": "n_12", "width": 1, "time": 7}, {"source": "n_1", "target": "n_9", "width": 1, "time": 7}, {"source": "n_9", "target": "n_1", "width": 1, "time": 7}, {"source": "n_9", "target": "n_2", "width": 1, "time": 7}, {"source": "n_11", "target": "n_2", "width": 1, "time": 7}, {"source": "n_12", "target": "n_1", "width": 1, "time": 7}, {"source": "n_12", "target": "n_2", "width": 1, "time": 7}, {"source": "n_13", "target": "n_2", "width": 1, "time": 7}, {"source": "n_2", "target": "n_15", "width": 1, "time": 8}, {"source": "n_2", "target": "n_17", "width": 1, "time": 8}, {"source": "n_2", "target": "n_14", "width": 1, "time": 8}, {"source": "n_2", "target": "n_3", "width": 1, ...
