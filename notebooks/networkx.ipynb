# %% [markdown]
# # git2net analysis for the networkx repository
#
# First we clone the repo

# %%
import pygit2 as git2
import os
import shutil
import git2net
import pathpy as pp
import sqlite3
import pandas as pd
from datetime import date, datetime, timedelta
import matplotlib.pyplot as plt
import json 
import math
import copy

git_repo_url = 'https://github.com/networkx/networkx.git'
local_directory = '.'
git_repo_dir = 'repos/networkx4analysis'
sqlite_db_file = 'databases/networkx/networkx_rename.db'

# %% [markdown]
# Clone repo:

# %%
if os.path.exists(git_repo_dir):
    shutil.rmtree(git_repo_dir)

repo = git2.clone_repository(git_repo_url, git_repo_dir) # Clones a non-bare repository

# %% [markdown]
# Then we create the database for it. We will try with max_modification=100, so that most commits are processed.
#
# Mine repo:

# %%
# Remove database if exists
#if os.path.exists(sqlite_db_file):
#    os.remove(sqlite_db_file)

max_modifications = 100
    
git2net.mine_git_repo(git_repo_dir, sqlite_db_file, max_modifications=max_modifications)
# Out:
# Found no database on provided path. Starting from scratch.
# Parallel (8 processes):   0%|          | 0/6437 [00:00<?, ?it/s]
# Commit exceeding max_modifications:  e256f9e622ffbf89e3b3694dc6bc813b7461c509
# Commit exceeding max_modifications:  36bf7ba5c5e8a10f79d211c99dfd9ccfac1d826d
# Parallel (8 processes):   1%|▏         | 86/6437 [00:44<38:35,  2.74it/s]
# Commit exceeding max_modifications:  ad25ae40af532158bf1d6765d0dc822d67bcbcb3
# Parallel (8 processes):   3%|▎         | 222/6437 [01:44<46:44,  2.22it/s]
# Commit exceeding max_modifications:  c585bf422f2ff040d2182c272f4dd3351626b9e9
# Parallel (8 processes):  10%|▉         | 642/6437 [03:19<19:10,  5.04it/s]
# Commit exceeding max_modifications:  3710816683aa8c535d9f8bcfc7432bc9d4068585
# Parallel (8 processes):  15%|█▍        | 935/6437 [04:25<19:21,  4.74it/s]
# Commit exceeding max_modifications:  c651135b22dc555e37db71e0f4dfeaa2046dd5a7
# Parallel (8 processes):  15%|█▍        | 936/6437 [04:25<17:46,  5.16it/s]
# Parallel (8 processes):  15%|█▌        | 979/6437 [04:31<18:02,  5.04it/s]
# Commit exceeding max_modifications:  ac04340c3a1a7b6df64f07a6e7329608d7ec08dd
# Parallel (8 processes):  15%|█▌        | 992/6437 [04:34<18:29,  4.91it/s]
# Commit exceeding max_modifications:  9f4fcae29a0aec8a26d3d4646ca3356940560ee6
# Parallel (8 processes):  20%|█▉        | 1270/6437 [05:19<15:22,  5.60it/s]
# Commit exceeding max_modifications:  c9471efb338c5b682867eee906463f7489ab1804
# Parallel (8 processes):  20%|██        | 1301/6437 [05:27<16:57,  5.05it/s]
# Commit exceeding max_modifications:  aa02955691df0fb6512b0214df0cdfc07ec89734
# Parallel (8 processes):  20%|██        | 1303/6437 [05:28<27:43,  3.09it/s]
# Commit exceeding max_modifications:  8280b7f9827df0fab99dc1cb7996ac3b7b9b3cff
# Parallel (8 processes):  21%|██        | 1337/6437 [05:33<13:26,  6.33it/s]
# Commit exceeding max_modifications:  66b45dce45eeaafa005a94ef36686a0a200ff6ad
# Parallel (8 processes):  25%|██▌       | 1638/6437 [06:12<09:02,  8.85it/s]
# Commit exceeding max_modifications:  74e0b8d695649b63ea793cfa784e6dad7244c47f
# Parallel (8 processes):  26%|██▌       | 1650/6437 [06:14<10:00,  7.98it/s]
# Commit exceeding max_modifications:  24d75f3dfb0eac856fedd6b19d29b756cd4eb2a1
# Parallel (8 processes):  30%|██▉       | 1927/6437 [06:53<14:31,  5.17it/s]
# Commit exceeding max_modifications:  9be53c9587e670728ffcfe43cd76ed138f6adb3d
# Parallel (8 processes):  31%|███       | 1990/6437 [07:01<12:11,  6.08it/s]
# Commit exceeding max_modifications:  64c5b87534b11e336dccd093c8e18f3c28548c8b
# Parallel (8 processes):  32%|███▏      | 2068/6437 [07:12<12:20,  5.90it/s]
# Commit exceeding max_modifications:  07008e8d93cb842b0f797d70c96601bf61caa231
# Parallel (8 processes):  32%|███▏      | 2086/6437 [07:15<13:17,  5.45it/s]
# Commit exceeding max_modifications:  3a7ae8ebcbfc52a111dddaf5d131547421f98070
# Parallel (8 processes):  35%|███▌      | 2261/6437 [07:43<08:28,  8.21it/s]
# Commit exceeding max_modifications:  da15b7b1111d39183cc3dfb1c8192859ff99ddc5
# Parallel (8 processes):  35%|███▌      | 2271/6437 [07:45<11:49,  5.87it/s]
# Commit exceeding max_modifications: 05ec96599fb6b8039e542dd510a064086d160eb7
# Parallel (8 processes):  35%|███▌      | 2272/6437 [07:45<14:00,  4.95it/s]
# Commit exceeding max_modifications:  675e2567c2a9e2ec0825ecf5e668edacdf35c4e8
# Commit exceeding max_modifications:  8762d5cca44e68e4795ef4d74c220768077a6e97
# Parallel (8 processes):  38%|███▊      | 2442/6437 [08:14<06:54,  9.64it/s]
# Commit exceeding max_modifications:  bfd855fe9e503a922faff1f490a99cbadc9456f5
# Commit exceeding max_modifications:  c06c61848447157a200f01f924f9cdeb8309ed1c
# Parallel (8 processes):  38%|███▊      | 2454/6437 [08:17<15:17,  4.34it/s]
# Commit exceeding max_modifications:  dd209dc852e80d88486fa922232be00180aff179
# Parallel (8 processes):  40%|████      | 2592/6437 [08:35<07:30,  8.54it/s]
# Commit exceeding max_modifications:  a866256a17529eb64081f2b5cfdbd6fe14fb675f
# Parallel (8 processes):  41%|████      | 2618/6437 [08:39<12:33,  5.07it/s]
# Commit exceeding max_modifications:  c7af34adfebd0a4459da84c424da9362b2cfeb03
# Parallel (8 processes):  42%|████▏     | 2679/6437 [08:49<08:54,  7.03it/s]
# Commit exceeding max_modifications:  0e03b6dd37e31f54519cc64f3604cb1eb6bf2409
# Commit exceeding max_modifications:  ba07ad7ac582204dfa63cbefe77ef3f058b0202d
# Parallel (8 processes):  42%|████▏     | 2680/6437 [08:49<09:51,  6.35it/s]
# Commit exceeding max_modifications:  74987369ff112fe2eda853d31444671609b474d3
# Parallel (8 processes):  42%|████▏     | 2708/6437 [08:53<10:45,  5.77it/s]
# Commit exceeding max_modifications:  5b82edacbb78c023fb4b326f4714e9a8ab15563f
# Commit exceeding max_modifications:  e9c695c52c35ebd5ce94ba2e5493b0f675e5dee2
# Parallel (8 processes):  42%|████▏     | 2715/6437 [08:54<09:39,  6.43it/s]
# Commit exceeding max_modifications:
# Parallel (8 processes):  42%|████▏     | 2717/6437 [08:55<09:02,  6.86it/s]
# 75c282b6b79252fa2fad876039ed4dc9ae7d95f5
# Parallel (8 processes):  43%|████▎     | 2742/6437 [08:59<11:25,  5.39it/s]
# Commit exceeding max_modifications:  f218eb1ab38e00b725077cfefe65bc95f795dfcd
# Parallel (8 processes):  43%|████▎     | 2743/6437 [08:59<12:34,  4.90it/s]
# Commit exceeding max_modifications:  0123ddafd8183613f579765b9b7fd87db39678b6
# Commit exceeding max_modifications:  8d236501d66c4f52984399783ac38bd435f5555b
# Parallel (8 processes):  46%|████▌     | 2966/6437 [09:38<06:00,  9.63it/s]
# Commit exceeding max_modifications:  023e1a5323ecf766aaed529429ebbb57d0842b55
# Parallel (8 processes):  47%|████▋     | 3004/6437 [09:42<07:25,  7.71it/s]
# Commit exceeding max_modifications:  75ab97d2384a87722028cdd436c92c71481e66e0
# Parallel (8 processes):  48%|████▊     | 3060/6437 [09:52<08:57,  6.28it/s]
# Commit exceeding max_modifications:  a12d659393a8b70d76cbfbd6c3a72baa3c97f1c1
# Parallel (8 processes):  49%|████▊     | 3126/6437 [10:01<07:01,  7.86it/s]
# Commit exceeding max_modifications:  bbd1d12a5887fd2a238c2b71898206aa462acb2f
# Parallel (8 processes):  49%|████▉     | 3140/6437 [10:03<07:58,  6.88it/s]
# Commit exceeding max_modifications:  fc6293f9887f575ff379c0da104af765e6b6240a
# Parallel (8 processes):  51%|█████     | 3284/6437 [10:23<07:27,  7.05it/s]
# Commit exceeding max_modifications:  b125e53a0f987b1ebacfc5e0af31f392014856ae
# Parallel (8 processes):  51%|█████     | 3298/6437 [10:25<10:39,  4.91it/s]
# Commit exceeding max_modifications:  e8233c0a5985ff96d75facbb64a8d18c992b0c0b
# Parallel (8 processes):  52%|█████▏    | 3338/6437 [10:31<08:32,  6.04it/s]
# Commit exceeding max_modifications:  8ed1344bf5d2d520a7c006983599bdfb5c87bd94
# Parallel (8 processes):  52%|█████▏    | 3361/6437 [10:34<06:27,  7.93it/s]
# Commit exceeding max_modifications:  de7952482a2ced56e97df895f2829f22be27818b
# Parallel (8 processes):  52%|█████▏    | 3371/6437 [10:36<07:39,  6.68it/s]
# Commit exceeding max_modifications:  14685f22178046e9572b584f5c4a15b20952ef93
# Parallel (8 processes):  52%|█████▏    | 3372/6437 [10:36<08:06,  6.31it/s]
# Commit exceeding max_modifications:  9b033b41486f9a5cf6bc4a8b71933ac2568129bd
# Parallel (8 processes):  52%|█████▏    | 3373/6437 [10:36<08:51,  5.76it/s]
# Commit exceeding max_modifications:  bb08034f111727b90851d239db19714049c40528
# Commit exceeding max_modifications:  2f6d8c418366d72b087d57546299b18806134f0c
# Parallel (8 processes):  54%|█████▎    | 3459/6437 [10:45<06:25,  7.73it/s]
# Commit exceeding max_modifications:  ffb2c8d4dde05f8ef9984648cba5851d63ce3cdf
# Parallel (8 processes):  54%|█████▍    | 3490/6437 [10:49<09:16,  5.29it/s]
# Commit exceeding max_modifications:  ea2605a874f9f2cfaa4d3a54edbc876172952782
# Parallel (8 processes):  54%|█████▍    | 3496/6437 [10:50<07:21,  6.66it/s]
# Commit exceeding max_modifications:  4473b669698474a2a0057eeb5ca62bd56c6a8de4
# Parallel (8 processes):  54%|█████▍    | 3500/6437 [10:51<07:39,  6.39it/s]
# Commit exceeding max_modifications:  3590698d6cba5a376ea7225a4e2a230447fa8fc0
# Parallel (8 processes):  55%|█████▍    | 3520/6437 [10:54<07:50,  6.20it/s]
# Commit exceeding max_modifications:  992eec97fa68647ccd67f6e1f3faa743a443247e
# Parallel (8 processes):  55%|█████▍    | 3537/6437 [11:03<29:45,  1.62it/s]
# Commit exceeding max_modifications:  fc1d3928612a688eb9f8713ac13f5a2e69657166
# Parallel (8 processes):  55%|█████▍    | 3538/6437 [11:04<26:44,  1.81it/s]
# Commit exceeding max_modifications:  f9155aa7eccecd7f312edea8ecb184c5041f2f3c
# Commit exceeding max_modifications:  023da239fb5f76eca2107db312db39fa4f4c206b
# Parallel (8 processes):  63%|██████▎   | 4035/6437 [12:08<05:25,  7.38it/s]
# Commit exceeding max_modifications:
# Parallel (8 processes):  63%|██████▎   | 4036/6437 [12:08<05:36,  7.13it/s]
# 8f1bcdf8cdee38517ba64754bf2e3f693f6aaa7e
# Commit exceeding max_modifications:  a6b5d901682e1c5f0cf9e8057979f9c1fd2a5735
# Parallel (8 processes):  63%|██████▎   | 4037/6437 [12:08<05:24,  7.40it/s]
# Commit exceeding max_modifications:  557d1e56222ad14c98e0d5091bb8b57c75a23e83
# Parallel (8 processes):  67%|██████▋   | 4299/6437 [12:42<03:25, 10.38it/s]
# Commit exceeding max_modifications:  471294a157b6cec8d53c36f9e6ceb5ff44c692e1
# Parallel (8 processes):  67%|██████▋   | 4305/6437 [12:43<03:43,  9.54it/s]
# Commit exceeding max_modifications:  65115bc9e15760ec4925796ae48b75d4c8b61b9e
# Parallel (8 processes):  67%|██████▋   | 4307/6437 [12:43<04:15,  8.33it/s]
# Commit exceeding max_modifications:  121335053f10f8a7af648bacb36d6300fc1953f6
# Parallel (8 processes):  69%|██████▉   | 4459/6437 [12:59<05:45,  5.73it/s]
# Commit exceeding max_modifications:  2c6740efbebf56fc28686bc01c49f541f307d353
# Parallel (8 processes):  73%|███████▎  | 4680/6437 [13:26<03:09,  9.29it/s]
# Commit exceeding max_modifications:  1eaee18a17512e6260ab4764e71f79b8e9f7ba99
# Parallel (8 processes):  73%|███████▎  | 4713/6437 [13:31<04:12,  6.82it/s]
# Commit exceeding max_modifications:  ea3a8826385f543775e2c6b147cbffcd289527da
# Parallel (8 processes):  73%|███████▎  | 4714/6437 [13:31<04:37,  6.21it/s]
# Commit exceeding max_modifications:  7e63811866e86e87e244790b5310098737c22ec4
# Parallel (8 processes):  76%|███████▌  | 4874/6437 [13:56<04:52,  5.35it/s]
# Commit exceeding max_modifications:  33980ffeef6de64fa543692bcc713e2b1fcdbcce
# Parallel (8 processes):  76%|███████▌  | 4875/6437 [13:56<04:20,  6.00it/s]
# Parallel (8 processes):  77%|███████▋  | 4979/6437 [14:10<05:15,  4.63it/s]
# Commit exceeding max_modifications:  67bb8deac5e06fd89079ffa4ea37d58ae527bdb3
# Parallel (8 processes):  77%|███████▋  | 4980/6437 [14:10<05:05,  4.78it/s]
# Commit exceeding max_modifications:  75e0c43bef21f764c669244fb57f658b4afc94e9
# Parallel (8 processes):  78%|███████▊  | 5038/6437 [14:16<01:43, 13.51it/s]
# Commit exceeding max_modifications:  a78a5a2a9fc260af506d225d46fd41b866e12ce5
# Parallel (8 processes):  79%|███████▉  | 5088/6437 [14:22<03:08,  7.16it/s]
# Commit exceeding max_modifications:  dc73628a6291e470d76d42e9efaa6e09599d8ce8
# Parallel (8 processes):  79%|███████▉  | 5090/6437 [14:22<03:08,  7.15it/s]
# Commit exceeding max_modifications:  4de84c9cdf1bed8248dc149317cb79fa46b545e8
# Parallel (8 processes):  80%|███████▉  | 5128/6437 [14:28<02:45,  7.92it/s]
# Commit exceeding max_modifications:  cd2bde7856dc8057c8269696110ffb75795edf13
# Parallel (8 processes):  80%|███████▉  | 5130/6437 [14:28<03:22,  6.46it/s]
# Commit exceeding max_modifications:  89daa927a0135a79cc69a75a3c89202158fa2ca7
# Parallel (8 processes):  80%|████████  | 5166/6437 [14:32<02:41,  7.85it/s]
# Commit exceeding max_modifications:  0cd14f622daa0b70dcb1b8f3404e70383354fceb
# Parallel (8 processes):  82%|████████▏ | 5250/6437 [14:43<04:21,  4.53it/s]
# Commit exceeding max_modifications:  3351206a3ce5b3a39bb2fc451e93ef545b96c95b
# Parallel (8 processes):  82%|████████▏ | 5256/6437 [14:44<02:55,  6.74it/s]
# Commit exceeding max_modifications:  b22d6b36ce0545995c99d233546e8a1fe7e27fc5
# Parallel (8 processes):  82%|████████▏ | 5288/6437 [14:49<03:50,  4.97it/s]
# Commit exceeding max_modifications:  99fc1bb6690ac1a45124db2a01c12fd64dcb109b
# Parallel (8 processes): 100%|█████████▉| 6436/6437 [17:25<00:00,  7.69it/s]Process ForkPoolWorker-6:
# Timeout processing commit:
# Process ForkPoolWorker-5:
# Parallel (8 processes): 100%|█████████▉| 6436/6437 [20:43<00:00,  5.18it/s]Process ForkPoolWorker-8:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-7:
# Traceback (most recent call last):
# 1b390c8314ec188b1702c8419a650baa2c376601
# Traceback (most recent call last):
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/queues.py", line 356, in get
#     res = self._reader.recv_bytes()
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#
# Process ForkPoolWorker-4:
# Traceback (most recent call last):
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/csepanyi/anaconda3/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/multiprocessing/pool.py in next(self, timeout)
#     850             try:
# --> 851                 item = self._items.popleft()
#     852             except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/git2net/extraction.py in _process_repo_parallel(git_repo_dir, sqlite_db_file, commits, extraction_settings)
#    1169                   .format(extraction_settings['no_of_processes'])) as pbar:
# -> 1170             for result in p.imap_unordered(_process_commit, args, chunksize=extraction_settings['chunksize']):
#    1171                 with sqlite3.connect(sqlite_db_file) as con:
#
# ~/anaconda3/lib/python3.8/multiprocessing/pool.py in next(self, timeout)
#     855                     raise StopIteration from None
# --> 856                 self._cond.wait(timeout)
#     857                 try:
#
# ~/anaconda3/lib/python3.8/threading.py in wait(self, timeout)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-9d13627a55d2> in <module>
#       5 max_modifications = 100
#       6
# ----> 7 git2net.mine_git_repo(git_repo_dir, sqlite_db_file, max_modifications=max_modifications)
#
# ~/anaconda3/lib/python3.8/site-packages/git2net/extraction.py in mine_git_repo(git_repo_dir, sqlite_db_file, commits, use_blocks, no_of_processes, chunksize, exclude, blame_C, blame_w, max_modifications, timeout, extract_text, extract_complexity, extract_merges, extract_merge_deletions, all_branches)
#    1568
#    1569     if extraction_settings['no_of_processes'] > 1:
# -> 1570         _process_repo_parallel(git_repo_dir, sqlite_db_file, u_commits, extraction_settings)
#    1571     else:
#    1572         _process_repo_serial(git_repo_dir, sqlite_db_file, u_commits, extraction_settings)
#
# ~/anaconda3/lib/python3.8/site-packages/git2net/extraction.py in _process_repo_parallel(git_repo_dir, sqlite_db_file, commits, extraction_settings)
#    1174                     if not result['commit'].empty:
#    1175                         result['commit'].to_sql('commits', con, if_exists='append', index=False)
# -> 1176                 pbar.update(1)
#    1177
#    1178
#
# ~/anaconda3/lib/python3.8/multiprocessing/pool.py in __exit__(self, exc_type, exc_val, exc_tb)
#     734
#     735     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 736         self.terminate()
#     737
#     738 #
#
# ~/anaconda3/lib/python3.8/multiprocessing/pool.py in terminate(self)
#     652         util.debug('terminating pool')
#     653         self._state = TERMINATE
# --> 654         self._terminate()
#     655
#     656     def join(self):
#
# ~/anaconda3/lib/python3.8/multiprocessing/util.py in __call__(self, wr, _finalizer_registry, sub_debug, getpid)
#     222                 sub_debug('finalizer calling %s with args %s and kwargs %s',
#     223                           self._callback, self._args, self._kwargs)
# --> 224                 res = self._callback(*self._args, **self._kwargs)
#     225             self._weakref = self._callback = self._args = \
#     226                             self._kwargs = self._key = None
#
# ~/anaconda3/lib/python3.8/multiprocessing/pool.py in _terminate_pool(cls, taskqueue, inqueue, outqueue, pool, change_notifier, worker_handler, task_handler, result_handler, cache)
#     690
#     691         util.debug('helping task handler/workers to finish')
# --> 692         cls._help_stuff_finish(inqueue, task_handler, len(pool))
#     693
#     694         if (not result_handler.is_alive()) and (len(cache) != 0):
#
# ~/anaconda3/lib/python3.8/multiprocessing/pool.py in _help_stuff_finish(inqueue, task_handler, size)
#     670         # task_handler may be blocked trying to put items on inqueue
#     671         util.debug('removing tasks from inqueue until task handler finished')
# --> 672         inqueue._rlock.acquire()
#     673         while task_handler.is_alive() and inqueue._reader.poll():
#     674             inqueue._reader.recv()
#
# KeyboardInterrupt:

# %% [markdown]
# Let's check the commits that had more than 100 files modified

# %%
git2net.mining_state_summary(git_repo_dir, sqlite_db_file)
# Out:
#   1%|▏         | 1/80 [00:00<00:12,  6.20it/s]
# 6357 / 6437 (98.76%) of commits were successfully mined.
# 100%|██████████| 80/80 [00:07<00:00, 11.14it/s]
#                                         hash  is_merge  modifications  \
# 0   e256f9e622ffbf89e3b3694dc6bc813b7461c509     False            136
# 1   36bf7ba5c5e8a10f79d211c99dfd9ccfac1d826d     False            132
# 2   ad25ae40af532158bf1d6765d0dc822d67bcbcb3     False            215
# 3   c585bf422f2ff040d2182c272f4dd3351626b9e9     False            132
# 4   3710816683aa8c535d9f8bcfc7432bc9d4068585      True            103
# ..                                       ...       ...            ...
# 75  0cd14f622daa0b70dcb1b8f3404e70383354fceb     False            227
# 76  b22d6b36ce0545995c99d233546e8a1fe7e27fc5     False            450
# 77  3351206a3ce5b3a39bb2fc451e93ef545b96c95b      True            483
# 78  99fc1bb6690ac1a45124db2a01c12fd64dcb109b     False            139
# 79  1b390c8314ec188b1702c8419a650baa2c376601     False              2
#
#        author_name              author_email          author_date
# 0             aric                 none@none  2005-07-12 23:35:35
# 1             aric                 none@none  2005-07-13 19:54:28
# 2             aric                 none@none  2008-11-03 04:37:22
# 3       loicseguin                 none@none  2010-08-02 14:50:33
# 4     Aric Hagberg    aric.hagberg@gmail.com  2013-01-12 06:23:58
# ..             ...                       ...                  ...
# 75  Jarrod Millman  jarrod.millman@gmail.com  2019-12-30 23:57:56
# 76  Jarrod Millman  jarrod.millman@gmail.com  2020-07-09 23:12:10
# 77  Jarrod Millman  jarrod.millman@gmail.com  2020-07-10 10:18:46
# 78  Jarrod Millman  jarrod.millman@gmail.com  2020-08-19 13:56:18
# 79  Jarrod Millman  jarrod.millman@gmail.com  2020-11-24 15:44:05
#
# [80 rows x 6 columns]

# %% [markdown]
# ### Database modification
# Replacing the names with number for compatibility with a temporal network.

# %%
con = sqlite3.connect(sqlite_db_file)

# Query the db
data = pd.read_sql("""SELECT * FROM commits""", con)

rename_auth = {}
rename_committer = {}

i = 1
for name in data['author_name'].unique():
    rename_auth[name] = i
    i = i + 1

i = 1
for name in data['committer_name'].unique():
    rename_committer[name] = i
    i = i + 1

data = data.replace({'author_name': rename_auth})
data = data.replace({'committer_name': rename_committer})

data.to_sql('commits', con, if_exists='replace')

f = open('networkx_authors.json', 'w')
f.write(json.dumps(rename_auth))
f.close()

f = open('networkx_committers.json', 'w')
f.write(json.dumps(rename_committer))
f.close()

# %% [markdown]
# ### Co-author networks

# %% [markdown]
# The network is too complex because we consider the whole timeframe of the repository since its creation. Therefore we need to filter the time dimensin, and in order to do that we nee to find the first and last commit in the repo.

# %%
db = sqlite3.connect(sqlite_db_file)
max_date = datetime.strptime(pd.read_sql_query("SELECT max(committer_date) as max FROM commits", db)['max'].item(), '%Y-%m-%d %H:%M:%S')
min_date = datetime.strptime(pd.read_sql_query("SELECT min(committer_date) as min FROM commits", db)['min'].item(), '%Y-%m-%d %H:%M:%S')

print('Min date: ', min_date)
print('Max date: ', max_date)
# Out:
# Min date:  2005-07-13 19:58:39
# Max date:  2021-03-08 21:19:46

# %% [markdown]
# In order not to select an 'empty' time period (relatively few commits, e.g. holiday season), it's also worth observing the number of commits over time.

# %%
pdCommits = pd.read_sql_query("SELECT * FROM commits", db)

days = {(min_date+timedelta(days=x)).date() : 0 for x in range((max_date-min_date).days + 1)}

commit_dates = pdCommits['committer_date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S').date()).value_counts()

for key in commit_dates.keys():
    days[key] = commit_dates.get(key)

keys = days.keys()
values = days.values()
plt.figure(figsize=(20,5))
plt.bar(keys, values)
# Out:
# <BarContainer object of 5718 artists>

# %% [markdown]
# ## Bipartite networks
# Because our network changes over time, we would like to visualize each year consecutively one after the other. We can use the pathpy temporal networks for this.

# %%
def collab_network(sqlite_db_file, t, node_info, min_date, max_date):
    start = int(datetime.timestamp(min_date))
    end = int(datetime.timestamp(max_date))

    n = pp.Network.from_temporal_network(t, min_time=start, max_time=end)

    new_n = copy.deepcopy(n)
    
    for node in n.nodes:
        if node_info['class'][node] == 'file':
            new_n.remove_node(node)

    for node in new_n.nodes:
        for f in n.successors[node]:
            for pre in n.predecessors[f]:
                if not node == pre:
                    new_n.add_edge(node, pre)

    return new_n

# %%
t, node_info, edge_info = git2net.get_bipartite_network(sqlite_db_file)

# %%
time_from = datetime(2010, 1, 1)
time_to = datetime(2016, 12, 31)
interval = timedelta(days=60)
delta = timedelta(days=7)

t2 = pp.TemporalNetwork()

rounds = math.ceil((time_to - time_from - interval)/delta)+1
for i in range(1,rounds):
    print('Round {i}/{r}'.format(i=i, r=rounds), end = "\r")
    start = time_from + i * delta
    end = time_from + i * delta + interval
    network = collab_network(sqlite_db_file, t, node_info, start, end)

    for edge in network.edges:
        t2.add_edge(edge[0], edge[1], i)

style = {    
  'ts_per_frame': 1, 
  'ms_per_frame': 700,
  'look_ahead': 0, 
  'look_behind': 60, 
  'inactive_edge_width': 2,
  'active_edge_width': 4, 
  'label_color' : '#000000',
  'label_size' : '8px',
  'label_offset': [0,5]
  }
print(t2)
pp.visualisation.plot(t2, **style)
# Out:
# Nodes:			1568
# Time-stamped links:	7272
# Links/Nodes:		46.61538461538461
# Observation period:	[1, 357]
# Observation length:	 356
# Time stamps:		 337
# Avg. inter-event dt:	 1.0595238095238095
# Min/Max inter-event dt:	 1/8
# <style>
#     text.active_bPBTKJtk {
#         text-anchor: middle;
#         font-size: 8px;
#         font-family: Arial, Helvetica, sans-serif;
#         fill: #000000;
#         opacity: 1.0;
#     }
#     text.hidden_bPBTKJtk {
#         opacity: 0;
#     }
#     line.tlinks_bPBTKJtk {
#         stroke: #cccccc;
#         stroke-opacity: 0.4;
#         stroke-width: 2;
#     }
#     line.active_bPBTKJtk {
#         stroke: #ff0000;
#         stroke-opacity: 1.0;
#         stroke-width: 4;
#     }
#     line.hidden_bPBTKJtk {
#         stroke: rgb(255, 255, 255);
#         stroke-opacity: 0;
#         stroke-width: 0px;
#     }
#     circle.active_bPBTKJtk {
#         stroke: #222;
#         fill: #ff0000;
#         fill-opacity: 1;
#         stroke-width: 2px;
#     }
#     circle.tnodes_bPBTKJtk {
#         fill: #cccccc;
#         stroke: #222;
#         fill-opacity: 1;
#         stroke-width: 1.5px;
#     }
# </style>
#
# <svg width="400" height="400" id="bPBTKJtk">
#     <text x="10" y="20" font-family="sans-serif" font-size="14px" fill="red"
#         id='bPBTKJtk_time_txt'>t</text>
#     <text x="120" y="20" font-family="sans-serif" font-size="14px" fill="#9999bb" style="cursor: pointer"
#         id='bPBTKJtk_start_txt'>stop</text>
#     <text x="170" y="20" font-family="sans-serif" font-size="14px" fill="#9999bb" style="cursor: pointer"
#         id='bPBTKJtk_restart_txt'>restart</text>
# </svg>
#
# <script charset="utf-8" src="https://d3js.org/d3.v4.min.js"></script>
# <script charset="utf-8">
#
# // Load via requireJS if available (jupyter notebook environment)
# try {
#     // Problem: require.config will raise an exception when called for the second time
#     require.config({
#         paths: {
#             //d3: "https://d3js.org/d3.v4.min"
#             d3: "https://d3js.org/d3.v4.min.js".replace(".js", "")
#         }
#     });
#     console.log("Detected requireJS");
# }
# catch(err){
#     // a reference error indicates that requireJS does not exist.
#     // other errors may occur due to multiple calls to config
#     if (err instanceof ReferenceError){
#         console.log("Detected no requireJS");
#
#         // Helper function that waits for d3js to be loaded
#         require = function require(symbols, callback) {
#             var ms = 5;
#             window.setTimeout(function(t) {
#                 if (window[symbols[0]])
#                     callback(window[symbols[0]]);
#                 else
#                     window.setTimeout(arguments.callee, ms);
#             }, ms);
#         }
#     }
# }
#
# require(["d3"], function(d3) {
#     d3.selection.prototype.moveToFront = function() {
#         return this.each(function(){
#             this.parentNode.appendChild(this);
#         });
#     };
#
#     d3.selection.prototype.moveToBack = function() {
#         return this.each(function() {
#             var firstChild = this.parentNode.firstChild;
#             if (firstChild) {
#                 this.parentNode.insertBefore(this, firstChild);
#             }
#         });
#     };
#
#     var svg = d3.select("#bPBTKJtk"),
#         width = +svg.attr("width"),
#         height = +svg.attr("height"),
#         radius = 5.0,
#         color = d3.scaleOrdinal(d3.schemeCategory20b);
#
#     var temporal_net = {"nodes": [{"id": "n_1", "group": 1}, {"id": "n_2", "group": 1}, {"id": "n_7", "group": 1}, {"id": "n_8", "group": 1}, {"id": "n_10", "group": 1}, {"id": "n_12", "group": 1}, {"id": "n_11", "group": 1}, {"id": "n_13", "group": 1}, {"id": "n_14", "group": 1}, {"id": "n_15", "group": 1}, {"id": "n_16", "group": 1}, {"id": "n_17", "group": 1}, {"id": "n_18", "group": 1}, {"id": "n_20", "group": 1}, {"id": "n_19", "group": 1}, {"id": "n_21", "group": 1}, {"id": "n_75", "group": 1}, {"id": "n_107", "group": 1}, {"id": "n_32", "group": 1}, {"id": "n_27", "group": 1}, {"id": "n_28", "group": 1}, {"id": "n_23", "group": 1}, {"id": "n_31", "group": 1}, {"id": "n_35", "group": 1}, {"id": "n_36", "group": 1}, {"id": "n_38", "group": 1}, {"id": "n_41", "group": 1}, {"id": "n_42", "group": 1}, {"id": "n_44", "group": 1}, {"id": "n_43", "group": 1}, {"id": "n_48", "group": 1}, {"id": "n_29", "group": 1}, {"id": "n_49", "group": 1}, {"id": "n_52", "group": 1}, {"id": "n_53", "group": 1}, {"id": "n_47", "group": 1}, {"id": "n_54", "group": 1}, {"id": "n_57", "group": 1}, {"id": "n_58", "group": 1}, {"id": "n_59", "group": 1}, {"id": "n_60", "group": 1}, {"id": "n_61", "group": 1}, {"id": "n_34", "group": 1}, {"id": "n_62", "group": 1}, {"id": "n_65", "group": 1}, {"id": "n_67", "group": 1}, {"id": "n_69", "group": 1}, {"id": "n_71", "group": 1}, {"id": "n_73", "group": 1}, {"id": "n_68", "group": 1}, {"id": "n_74", "group": 1}, {"id": "n_78", "group": 1}, {"id": "n_76", "group": 1}, {"id": "n_80", "group": 1}, {"id": "n_70", "group": 1}, {"id": "n_63", "group": 1}, {"id": "n_72", "group": 1}, {"id": "n_82", "group": 1}, {"id": "n_84", "group": 1}, {"id": "n_87", "group": 1}, {"id": "n_88", "group": 1}, {"id": "n_90", "group": 1}, {"id": "n_92", "group": 1}, {"id": "n_93", "group": 1}, {"id": "n_98", "group": 1}, {"id": "n_99", "group": 1}, {"id": "n_103", "group": 1}, {"id": "n_94", "group": 1}, {"id": "n_100", "group": 1}, {"id": "n_102", "group": 1}, {"id": "n_104", "group": 1}, {"id": "n_105", "group": 1}, {"id": "n_106", "group": 1}, {"id": "n_108", "group": 1}, {"id": "n_200", "group": 1}, {"id": "n_114", "group": 1}, {"id": "n_109", "group": 1}, {"id": "n_113", "group": 1}, {"id": "n_112", "group": 1}, {"id": "n_115", "group": 1}, {"id": "n_117", "group": 1}, {"id": "n_116", "group": 1}, {"id": "n_118", "group": 1}, {"id": "n_121", "group": 1}, {"id": "n_122", "group": 1}, {"id": "n_111", "group": 1}, {"id": "n_124", "group": 1}, {"id": "n_123", "group": 1}, {"id": "n_125", "group": 1}, {"id": "n_110", "group": 1}, {"id": "n_120", "group": 1}, {"id": "n_119", "group": 1}, {"id": "n_127", "group": 1}, {"id": "n_128", "group": 1}, {"id": "n_129", "group": 1}, {"id": "n_131", "group": 1}, {"id": "n_132", "group": 1}, {"id": "n_139", "group": 1}, {"id": "n_130", "group": 1}, {"id": "n_134", "group": 1}, {"id": "n_145", "group": 1}, {"id": "n_135", "group": 1}, {"id": "n_138", "group": 1}, {"id": "n_140", "group": 1}, {"id": "n_141", "group": 1}, {"id": "n_137", "group": 1}, {"id": "n_136", "group": 1}, {"id": "n_144", "group": 1}, {"id": "n_146", "group": 1}, {"id": "n_149", "group": 1}, {"id": "n_142", "group": 1}, {"id": "n_147", "group": 1}, {"id": "n_150", "group": 1}, {"id": "n_148", "group": 1}, {"id": "n_151", "group": 1}, {"id": "n_152", "group": 1}, {"id": "n_153", "group": 1}, {"id": "n_154", "group": 1}, {"id": "n_156", "group": 1}, {"id": "n_155", "group": 1}, {"id": "n_157", "group": 1}, {"id": "n_161", "group": 1}, {"id": "n_162", "group": 1}, {"id": "n_159", "group": 1}, {"id": "n_164", "group": 1}, {"id": "n_165", "group": 1}, {"id": "n_166", "group": 1}, {"id": "n_167", "group": 1}, {"id": "n_169", "group": 1}, {"id": "n_168", "group": 1}, {"id": "n_172", "group": 1}, {"id": "n_170", "group": 1}, {"id": "n_171", "group": 1}, {"id": "n_174", "group": 1}, {"id": "n_175", "group": 1}, {"id": "n_176", "group": 1}, {"id": "n_179", "group": 1}, {"id": "n_180", "group": 1}, {"id": "n_181", "group": 1}, {"id" ...

# %%
pp.visualisation.export_html(t, 'my_temporal_network.html', **style)

# %%
help(pp.Network.from_temporal_network)
# Out:
# Help on method from_temporal_network in module pathpy.classes.network:
#
# from_temporal_network(tempnet, min_time=None, max_time=None, directed=True) method of builtins.type instance
#     Returns a time-aggregated directed network representation
#     of a temporal network. The number of occurrences of
#     the same edge at different time stamps is captured
#     by edge weights.
